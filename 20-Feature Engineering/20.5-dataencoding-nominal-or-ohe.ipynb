# %% [markdown]
# ![Data Encoding.png](<attachment:Data Encoding.png>)

# %% [markdown]
# #### There are various techniques. We are going to see the following techniques:
# * Nominal/ OHE Encoding.
# * Label and Ordinal Encoding.
# * Target Guided Ordinal Encoding.
#
# #### Nominal/OHE Encoding
# * `One Hot Encoding`, also known as `Nominal Encoding`, is a technique used to represent categorical data as numerical data, which is more suitable for Machine Learning algorithms.
# * In this technique, each category is represented as a binary vector where each bit corresponds to a unique category.
# * For example, if we have a categorical variable "color" with three possible values (red, green, blue), we can represent it using one hot encoding as follows:
#
# 1) Red: [1, 0, 0]
# 2) Green: [0, 1, 0]
# 3) Blue: [0, 0, 1]

# %% [markdown]
# ![ohe.png](attachment:ohe.png)

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

## Create a dataframe
df = pd.DataFrame({
    'color':['red','green','blue','green','red']
})

# df.head()

encoder = OneHotEncoder()
encoded =encoder.fit_transform(df[['color']]).toarray()
encoded_df_updated = pd.DataFrame(encoded,columns=encoder.get_feature_names_out())

## To add new feature
encoder.transform([['blue']]).toarray()
# Out:
# c:\Users\saakh\Learning\AI_ML\Data_Analyst_Bootcamp\PythonBasic\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([[1., 0., 0.]])

# %%
pd.concat([df,encoded_df_updated], axis=1)
# Out:
#    color  color_blue  color_green  color_red
# 0    red         0.0          0.0        1.0
# 1  green         0.0          1.0        0.0
# 2   blue         1.0          0.0        0.0
# 3  green         0.0          1.0        0.0
# 4    red         0.0          0.0        1.0

# %%
## Internal assignment:
import seaborn as sns

sns.load_dataset('tips')
# Let us try doing the same excercise for sex, smoker, day, time
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Internal assignment:
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

df_tips=sns.load_dataset('tips')

encoder=OneHotEncoder()
encoded=encoder.fit_transform(df_tips[['sex']]).toarray()

df_tips_encoded=pd.DataFrame(encoded,columns=encoder.get_feature_names_out())
pd.concat([df_tips_encoded,df_tips],axis=1)
# Out:
#      sex_Female  sex_Male  total_bill   tip     sex smoker   day    time  size
# 0           1.0       0.0       16.99  1.01  Female     No   Sun  Dinner     2
# 1           0.0       1.0       10.34  1.66    Male     No   Sun  Dinner     3
# 2           0.0       1.0       21.01  3.50    Male     No   Sun  Dinner     3
# 3           0.0       1.0       23.68  3.31    Male     No   Sun  Dinner     2
# 4           1.0       0.0       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...       ...         ...   ...     ...    ...   ...     ...   ...
# 239         0.0       1.0       29.03  5.92    Male     No   Sat  Dinner     3
# 240         1.0       0.0       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         0.0       1.0       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         0.0       1.0       17.82  1.75    Male     No   Sat  Dinner     2
# 243         1.0       0.0       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]
