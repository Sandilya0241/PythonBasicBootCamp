# %% [markdown]
# ### Flask Framework - Web framework which is created with the Python programming language.
# * WSGI -> Web Server Gateway Interface
#
# ![image-2.png](attachment:image-2.png)
#
# * Jinja2 Template Engine
#     -   Web Template with a datasource (SQL DB, CSV, ML Model or MongoDB,...) to create dynamic web pages.
